# %%
import sys
from pathlib import Path

# добавляем папку src в PYTHONPATH
sys.path.append(str(Path(".").resolve() / "src"))

import pandas as pd
from eda_cli.core import compute_quality_flags

df = pd.read_csv("data/example.csv")
compute_quality_flags(df)
# Out:
# {'has_constant_columns': False,
#  'has_many_zero_values': True,
#  'has_high_cardinality_categoricals': False,
#  'has_suspicious_id_duplicates': True,
#  'quality_score': 0.7}

# %%
# !python -c "import sys; sys.path.append('src'); from eda_cli.cli import cli; cli()" report data/example.csv --out-dir reports_hw03 --title "HW03 EDA"

# %%
# !python -m pytest -q
# Out:
# =================================== ERRORS ====================================
# _____________________ ERROR collecting tests/test_core.py _____________________
# ImportError while importing test module 'C:\Users\slkri\ai-engineering-2025\homeworks\HW03\eda-cli\tests\test_core.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tests\test_core.py:3: in <module>
#     from eda_cli.core import compute_quality_flags
# E   ModuleNotFoundError: No module named 'eda_cli'
# =========================== short test summary info ===========================
# ERROR tests/test_core.py
# !!!!!!!!!!!!!!!!!!! Interrupted: 1 error during collection !!!!!!!!!!!!!!!!!!!!
# 1 error in 1.27s
